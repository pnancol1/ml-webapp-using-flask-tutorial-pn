# %%
import pandas as pd
import time
import datetime
import kagglehub
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       3 import datetime
#       4 import kagglehub
# ----> 5 import pmdarima as pdarm
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# ...

# %%
path = kagglehub.dataset_download("avis02/crime-data-from-2020-to-present")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/codespace/.cache/kagglehub/datasets/avis02/crime-data-from-2020-to-present/versions/1

# %%
total_data = pd.read_csv("/home/codespace/.cache/kagglehub/datasets/avis02/crime-data-from-2020-to-present/versions/1/Crime_Data_from_2020_to_Present.csv")

total_data
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1        200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2        200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3        200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4        200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630
# ...            ...                     ...                     ...       ...
# 1004842  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 1004843  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 1004844  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 1004845  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 1004846  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
total_data['DATE OCC2'] = pd.to_datetime(total_data['DATE OCC'])
total_data['year'] = total_data['DATE OCC2'].dt.year
total_data['year']
# Out:
# /tmp/ipykernel_2912/3671166298.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   total_data['DATE OCC2'] = pd.to_datetime(total_data['DATE OCC'])
# 0          2020
# 1          2020
# 2          2020
# 3          2020
# 4          2020
#            ...
# 1004842    2024
# 1004843    2024
# 1004844    2024
# 1004845    2024
# 1004846    2024
# Name: year, Length: 1004847, dtype: int32

# %%
recent_data = total_data.loc[total_data['year'] >= 2024]

recent_data
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 877322   241308462  04/18/2024 12:00:00 AM  04/17/2024 12:00:00 AM      1940
# 877323   241105924  02/20/2024 12:00:00 AM  02/17/2024 12:00:00 AM      2330
# 877324   241214023  08/02/2024 12:00:00 AM  08/01/2024 12:00:00 AM      2200
# 877325   241312224  08/15/2024 12:00:00 AM  08/14/2024 12:00:00 AM      2100
# 877326   240208601  04/06/2024 12:00:00 AM  04/04/2024 12:00:00 AM      1800
# ...            ...                     ...                     ...       ...
# 1004842  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 1004843  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 1004844  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 1004845  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 1004846  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
total_data = total_data.set_index(total_data["DATE OCC"])

# %%
import matplotlib.pyplot as plt

plt.hist(total_data["TIME OCC"])
plt.show()

# %%
total_data['DATE OCC2'] = total_data['DATE OCC2'].apply(lambda x: x.date())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 total_data['DATE OCC2'] = total_data['DATE OCC2'].apply(lambda x: x.date())
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
total_data['DATE OCC2']

crime_count = total_data.groupby(['DATE OCC2']).count()

# %%
cs = crime_count['DR_NO']

# %%
import matplotlib.pyplot as plt

fig, axis = plt.subplots(figsize = (10, 5))

plt.plot(cs)

plt.show()

# %%
model = pdarm.auto_arima(cs, seasonal = False, trace = True, m=7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import pmdarima as pdarm
#       3 model = pdarm.auto_arima(cs, seasonal = False, trace = True, m=7)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# ...
